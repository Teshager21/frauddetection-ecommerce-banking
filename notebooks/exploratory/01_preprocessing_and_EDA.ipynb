# %% [markdown]
# # 🧹 Data Preprocessing & EDA
# This notebook handles missing values, performs data cleaning, merges geolocation data, performs feature engineering, and prepares data for modeling.

# %% [markdown]
# ### 📦 Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import ipaddress

# %% [markdown]
# ## 📂 Load Data

# %%
fraud_df = pd.read_csv('../../data/raw/Fraud_Data.csv')
ip_df = pd.read_csv('../../data/raw/IpAddress_to_Country.csv')
cc_df = pd.read_csv('../../data/raw/creditcard.csv')

# %%
fraud_df.sample(5)
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 101157   345341  2015-05-09 15:36:30  2015-06-03 13:01:19              18
# 856      190496  2015-07-26 09:30:26  2015-08-21 20:09:18              30
# 140042    28267  2015-07-22 01:02:51  2015-07-24 17:54:58              50
# 52072    297815  2015-07-21 04:59:13  2015-08-12 03:06:23              34
# 73080    234125  2015-06-19 02:20:10  2015-07-09 03:06:14              38
#
#             device_id  source browser sex  age    ip_address  class
# 101157  CSWSYXXJQYJEQ     Ads  Chrome   F   36  3.787511e+09      0
# 856     VJYDTUKTVMFTJ  Direct  Safari   M   35  3.842933e+09      0
# 140042  BVKJREOYSBUFM     SEO      IE   M   32  1.365387e+09      0
# 52072   CEYEQAWGTVOZN  Direct  Chrome   M   29  2.300459e+09      0
# 73080   DLBTITZJRFMRZ     Ads  Chrome   F   41  1.445593e+09      0

# %%
ip_df.sample(5)
# Out:
#         lower_bound_ip_address  upper_bound_ip_address             country
# 54607             3.104713e+09              3104713727  Russian Federation
# 114992            3.406633e+09              3406633215               China
# 69361             3.230868e+09              3230868479       United States
# 18358             1.495267e+09              1495269375              Sweden
# 72237             3.233720e+09              3233720575       United States

# %%
cc_df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 125965   77878.0 -1.759075  0.213638  0.838361 -1.793215 -0.663088 -0.659998
# 122349   76527.0 -0.153722  0.086604  1.823014 -0.833608 -0.817505 -0.058096
# 193056  129974.0 -0.513990  1.086294  2.008046  4.557913  0.682915  1.272290
# 167918  118964.0  1.995431 -0.897238 -1.242638 -0.717488 -0.645081 -0.297513
# 8128     11030.0 -0.999581  1.069343  1.537029 -1.030109 -0.258109 -0.348464
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 125965 -0.665247  0.902891 -1.500009  ... -0.211032 -0.681568 -0.238735
# 122349 -0.397143  0.259415 -1.456034  ...  0.290229  0.711955 -0.042759
# 193056  0.074380  0.374332 -1.471273  ...  0.101431  0.419645 -0.413440
# 167918 -0.997411  0.088555 -0.188549  ...  0.321742  0.828099  0.094594
# 8128    0.021868  0.361678  0.708899  ...  0.125665  0.403617 -0.191658
#
#              V24       V25       V26       V27       V28  Amount  Class
# 125965 -0.273718  0.159588  1.009719 -0.408485 -0.162900    0.95      0
# 122349  0.212116 -0.613315 -0.203033  0.166172  0.130151    2.50      0
# 193056  0.679830  0.496347  0.683957  0.089250  0.089096    1.51      0
# 167918  0.602728 -0.205192 -0.142937  0.012529 -0.006165   69.99      0
# 8128    0.028897 -0.253035  0.818234 -0.251397  0.021326   15.95      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 🧼 Data Cleaning

# %% [markdown]
# ### Missing Values

# %%
#count missing values in the df
fraud_df.isna().sum()
# Out:
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64

# %%
#check for missing values in the ip df
ip_df.isna().sum()
# Out:
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64

# %%
#check for missing values in credit card df
cc_df.isna().sum().sum()
# Out:
# 0

# %%
# Convert timestamps
fraud_df['signup_time'] = pd.to_datetime(fraud_df['signup_time'])
fraud_df['purchase_time'] = pd.to_datetime(fraud_df['purchase_time'])

# Remove duplicates
fraud_df.drop_duplicates(inplace=True)

# %%
fraud_df
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
# [151112 rows x 11 columns]

# %%
fraud_df[fraud_df['user_id']==1359]
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
#
#        device_id source browser sex  age    ip_address  class
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1

# %%
ip_df.dtypes
# Out:
# lower_bound_ip_address    float64
# upper_bound_ip_address      int64
# country                    object
# dtype: object

# %% [markdown]
# ## 🌐 IP Geolocation Mapping

# %%
fraud_df['ip_int'] = fraud_df['ip_address'].astype(float).astype(int)

# Make sure bounds are int
ip_df['lower_bound_ip_address'] = ip_df['lower_bound_ip_address'].astype(int)
ip_df['upper_bound_ip_address'] = ip_df['upper_bound_ip_address'].astype(int)

# Merge based on range: use pd.merge_asof or manual interval join
merged_df = pd.merge_asof(
    fraud_df.sort_values('ip_int'),
    ip_df.sort_values('lower_bound_ip_address'),
    left_on='ip_int',
    right_on='lower_bound_ip_address',
    direction='backward'
)

# Make sure bounds are int
merged_df['lower_bound_ip_address'] = merged_df['lower_bound_ip_address'].fillna(-1).astype('int')
merged_df['upper_bound_ip_address'] = merged_df['upper_bound_ip_address'].fillna(-1).astype('int')

# Optional: filter where ip_int is also <= upper_bound_ip_address
merged_df = merged_df[merged_df['ip_int'] <= merged_df['upper_bound_ip_address']]

# %%
# Check how many are missing
missing = merged_df['country'].isna().sum()
print(f"Missing countries: {missing}")

# Option 1: Fill with 'Unknown'
merged_df['country'].fillna('Unknown', inplace=True)

# Option 2: Drop if you're okay losing those rows
# fraud_df = fraud_df.dropna(subset=['country'])
# Out:
# Missing countries: 0
# /tmp/ipykernel_1064975/2064027834.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['country'].fillna('Unknown', inplace=True)

# %%
merged_df.sample(5)
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 127266   390772 2015-03-27 00:47:40 2015-07-12 12:08:02              32
# 112895   318628 2015-04-17 11:43:38 2015-05-10 05:01:00              58
# 8897      35181 2015-04-22 23:56:51 2015-06-26 08:17:10              11
# 91576    234108 2015-01-18 08:03:18 2015-03-28 15:02:36              46
# 69080     23139 2015-07-28 06:59:12 2015-11-15 13:54:09               9
#
#             device_id  source  browser sex  age    ip_address  class  \
# 127266  LWTLZOXFHUBFI     SEO       IE   M   48  3.635993e+09      0
# 112895  WRHWYMWREVTWS  Direct       IE   M   29  3.231212e+09      0
# 8897    TZJGKQLFCIFGG     Ads   Safari   F   42  2.431771e+08      0
# 91576   AYXPNYNFSSATZ     SEO  FireFox   M   48  2.610384e+09      0
# 69080   DAWETKXLRDSQL     Ads       IE   M   44  1.977142e+09      0
#
#             ip_int  lower_bound_ip_address  upper_bound_ip_address  \
# 127266  3635992557              3635970048              3636002815
# 112895  3231212054              3231212032              3231212287
# 8897     243177066               242221056               243269631
# 91576   2610384022              2610364416              2610429951
# 69080   1977142457              1975517184              1979711487
#
#               country
# 127266  United States
# 112895    Switzerland
# 8897            China
# 91576   United States
# 69080           India

# %%
merged_df.isna().sum().sort_values(ascending=False)
# Out:
# user_id                   0
# signup_time               0
# purchase_time             0
# purchase_value            0
# device_id                 0
# source                    0
# browser                   0
# sex                       0
# age                       0
# ip_address                0
# class                     0
# ip_int                    0
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64

# %%
# Merge with country info
merged_df = pd.merge_asof(
    fraud_df.sort_values('ip_int'),
    ip_df.sort_values('lower_bound_ip_address'),
    left_on='ip_int', right_on='lower_bound_ip_address'
)
# Make sure bounds are int
merged_df['lower_bound_ip_address'] = merged_df['lower_bound_ip_address'].fillna(-1).astype('int')
merged_df['upper_bound_ip_address'] = merged_df['upper_bound_ip_address'].fillna(-1).astype('int')

# %%
merged_df.sample(5)
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 103626   157607 2015-01-06 06:01:57 2015-04-14 03:29:01              50
# 77268     66457 2015-01-02 12:16:13 2015-01-02 12:16:14              39
# 17767     36844 2015-06-22 10:44:51 2015-10-18 13:09:59              38
# 38670    204464 2015-06-14 15:47:57 2015-09-08 14:45:26              94
# 43281     65286 2015-04-09 12:00:19 2015-04-23 18:44:05              35
#
#             device_id source  browser sex  age    ip_address  class  \
# 103626  TFUYBVNWCZSFX    Ads  FireFox   F   19  2.961057e+09      0
# 77268   FFYVRWMTLSYPY    Ads  FireFox   M   32  2.202518e+09      1
# 17767   PIVAPUFFKHXEB    SEO  FireFox   M   34  4.886868e+08      0
# 38670   EVBRLIHLXGUEI    SEO   Chrome   F   40  1.110704e+09      0
# 43281   PVZCDFLNZYYRI    Ads   Chrome   F   25  1.235775e+09      0
#
#             ip_int  lower_bound_ip_address  upper_bound_ip_address  \
# 103626  2961057262              2961057024              2961057279
# 77268   2202518487              2202468352              2202533887
# 17767    488686795               486539264               503316479
# 38670   1110704285              1110704128              1110835199
# 43281   1235775131              1224736768              1241513983
#
#               country
# 103626        Ireland
# 77268   United States
# 17767   United States
# 38670   United States
# 43281   United States

# %% [markdown]
# ## 🧠 Feature Engineering

# %%
# Time since signup
merged_df['time_since_signup'] = (merged_df['purchase_time'] - merged_df['signup_time']).dt.total_seconds() / 3600
# Hour and day of transaction
# merged_df['hour_of_day'] = merged_df['purchase_time'].dt.hour
# merged_df['day_of_week'] = merged_df['purchase_time'].dt.dayofweek

merged_df['dayofweek'] = merged_df['purchase_time'].dt.dayofweek
merged_df['hour'] = merged_df['purchase_time'].dt.hour
merged_df['is_weekend'] = merged_df['purchase_time'].dt.dayofweek >= 5

merged_df.drop(columns=['purchase_time','signup_time'],inplace=True)

# %%
merged_df.sample(5)
# Out:
#         user_id  purchase_value      device_id  source  browser sex  age  \
# 76157    301321              22  BREXLYSXMSBIH  Direct   Chrome   M   45
# 67553    306182              38  JFRGGSPKFJSBD  Direct  FireFox   M   23
# 130950   141233              26  PUFHLHGVEVFHM     SEO   Chrome   F   42
# 55622    315550              34  NGFBKUSDRMCRH     SEO   Chrome   M   23
# 23582    228458              20  SSSTXKFVAPGXT  Direct   Safari   M   22
#
#           ip_address  class      ip_int  lower_bound_ip_address  \
# 76157   2.171739e+09      0  2171739074              2171731968
# 67553   1.936226e+09      0  1936225567              1936195584
# 130950  3.737276e+09      0  3737276399              3737124864
# 55622   1.571428e+09      0  1571427808              1571422208
# 23582   6.473742e+08      1   647374210               637534208
#
#         upper_bound_ip_address         country  time_since_signup  dayofweek  \
# 76157               2171797503   United States        2382.229722          5
# 67553               1936457727           China         479.479444          0
# 130950              3737387007           China         936.664722          1
# 55622               1571553279  Czech Republic         641.565556          5
# 23582                654311423   United States         283.407778          6
#
#         hour  is_weekend
# 76157     19        True
# 67553     11       False
# 130950    20       False
# 55622      0        True
# 23582      8        True

# %%
merged_df.rename(columns={
    'class': 'is_fraud',
    'ip_address': 'ip_address_raw'
}, inplace=True)

# %% [markdown]
# ### Rename columns

# %%
merged_df.sample()
# Out:
#         user_id  purchase_value      device_id source browser sex  age  \
# 141455    43730              47  NAMOUEGTBRCOQ    SEO  Chrome   M   28
#
#         ip_address_raw  is_fraud      ip_int  lower_bound_ip_address  \
# 141455    4.028427e+09         0  4028427130              3758096128
#
#         upper_bound_ip_address    country  time_since_signup  dayofweek  hour  \
# 141455              3758096383  Australia          1360.5975          3     5
#
#         is_weekend
# 141455       False

# %% [markdown]
# ### Reorder important columns

# %%
cols = [
    'user_id', 'time_since_signup', 'time_since_signup',
    'purchase_value', 'device_id', 'source', 'browser', 'sex', 'age',
    'ip_address_raw', 'ip_int', 'country', 'hour', 'dayofweek','is_weekend',
    'is_fraud'
]
final_df = merged_df[cols]

# %%
# Transaction frequency and velocity features
fraud_df.groupby('user_id')['purchase_time'].count()
fraud_df.groupby('device_id')['purchase_time'].nunique().sort_values(ascending=False)
# Out:
# device_id
# KIPFSCNUGOLDP    20
# NGQCKIADMZORL    20
# CQTUVBYIWWWBC    20
# ITUMJCKWEYNDD    20
# EQYVNEGOFLAWK    20
#                  ..
# IXVBQLPWSAIDA     1
# IXUYCZZVDXGPO     1
# IXUWTGATQJEVG     1
# IXUKDXQBVCYCZ     1
# ZZZXASJUVUNMV     1
# Name: purchase_time, Length: 137956, dtype: int64

# %%
#Handle Class Imbalance
fraud_df['class'].value_counts(normalize=True)
# Out:
# class
# 0    0.906354
# 1    0.093646
# Name: proportion, dtype: float64

# %%
final_df.sample(5)
# Out:
#         user_id  time_since_signup  time_since_signup  purchase_value  \
# 107147    64621        2617.706944        2617.706944              18
# 23430    290485        1693.424722        1693.424722              68
# 129621    89283        1383.159444        1383.159444              17
# 108087   294991        1842.256389        1842.256389              35
# 122363   327017         860.930556         860.930556              21
#
#             device_id  source  browser sex  age  ip_address_raw      ip_int  \
# 107147  ZVCDWXKLTZODS     SEO       IE   F   39    3.059105e+09  3059105182
# 23430   YGSLLUXMXOPSZ     Ads  FireFox   M   42    6.438692e+08   643869185
# 129621  BAJJCIJNEEIXZ  Direct       IE   M   31    3.699778e+09  3699778221
# 108087  QVSWOFKVZCBTP  Direct  FireFox   F   49    3.085132e+09  3085132255
# 122363  NFTVBIHBFYEKG     SEO   Chrome   F   23    3.503462e+09  3503462036
#
#                                 country  hour  dayofweek  is_weekend  is_fraud
# 107147                            China    18          5        True         0
# 23430                     United States     3          1       False         0
# 129621  Taiwan; Republic of China (ROC)    12          4       False         0
# 108087                            China     2          4       False         0
# 122363                    United States    10          6        True         1

# %% [markdown]
# ### Normalization and Scaling

# %%
# Choose numeric features to scale
numeric_features = ['purchase_value', 'age', 'time_since_signup', 'hour', 'dayofweek','is_weekend']

scaler = StandardScaler()
final_df[numeric_features] = scaler.fit_transform(final_df[numeric_features])

# Optional: view result
print(final_df[numeric_features].head())
# Out:
#    purchase_value       age  time_since_signup  time_since_signup      hour  \
# 0        0.494721  0.331793          -1.013679          -1.013679 -0.220124
# 1       -0.214781 -0.364448          -1.230613          -1.230613  0.792542
# 2       -0.214781 -0.132367          -1.337931          -1.337931 -0.509456
# 3       -0.214781  0.795954           0.800513           0.800513  1.371208
# 4        0.985915  0.563874          -1.127359          -1.127359 -0.654123
#
#    dayofweek  is_weekend
# 0   1.489476    1.568716
# 1   0.492565   -0.637464
# 2  -1.002803   -0.637464
# 3  -0.005891   -0.637464
# 4   1.489476    1.568716
# /tmp/ipykernel_1064975/770720336.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[numeric_features] = scaler.fit_transform(final_df[numeric_features])

# %% [markdown]
# ### Encoding Categorical Features

# %%
cols_to_encode=['source','browser','sex','country','device_id']
le = LabelEncoder()
for col in cols_to_encode:
    final_df[col] = le.fit_transform(final_df[col])
# Out:
# /tmp/ipykernel_1064975/197223539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[col] = le.fit_transform(final_df[col])
# /tmp/ipykernel_1064975/197223539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[col] = le.fit_transform(final_df[col])
# /tmp/ipykernel_1064975/197223539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[col] = le.fit_transform(final_df[col])
# /tmp/ipykernel_1064975/197223539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[col] = le.fit_transform(final_df[col])
# /tmp/ipykernel_1064975/197223539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[col] = le.fit_transform(final_df[col])

# %%
final_df.sample(5)
# Out:
#         user_id  time_since_signup  time_since_signup  purchase_value  \
# 82356     83582           0.437801           0.437801       -0.651398
# 2565     305525           0.543715           0.543715       -0.869706
# 110122    90441          -0.882434          -0.882434        1.367955
# 26884     37426          -0.003033          -0.003033        2.077457
# 91563     45266          -0.662795          -0.662795       -0.924284
#
#         device_id  source  browser  sex       age  ip_address_raw      ip_int  \
# 82356       35507       0        0    0  0.679914    2.343657e+09  2343656902
# 2565        23149       1        2    1  0.795954    6.938745e+07    69387447
# 110122      43410       2        0    1 -0.248408    3.154623e+09  3154623484
# 26884       64414       1        2    0 -0.016327    7.366414e+08   736641420
# 91563       31908       2        0    0  0.215753    2.610085e+09  2610084804
#
#         country      hour  dayofweek  is_weekend  is_fraud
# 82356       171 -0.075457  -1.501259   -0.637464         0
# 2565        171  0.503209   0.492565   -0.637464         0
# 110122       60 -1.666788  -1.002803   -0.637464         0
# 26884        84  0.792542  -0.005891   -0.637464         0
# 91563       171 -0.364790   0.492565   -0.637464         0

# %% [markdown]
# ### Save to CSV for modeling:

# %%
final_df.to_csv("../../data/interim/interim_fraud_data.csv", index=False)

# %%
final_df.sample(5)
# Out:
#         user_id  time_since_signup  time_since_signup  purchase_value  \
# 542      369157           0.223489           0.223489       -0.105627
# 58128     31864          -0.967919          -0.967919       -0.542244
# 84711    317088          -0.815130          -0.815130       -1.033438
# 127840   388080          -1.564185          -1.564185       -1.306323
# 124333   256718          -0.170268          -0.170268       -0.433090
#
#         device_id  source  browser  sex       age  ip_address_raw      ip_int  \
# 542         39976       2        2    1 -0.132367    1.450403e+07    14504026
# 58128       36424       0        0    1  0.679914    1.638991e+09  1638991029
# 84711       12299       1        0    0 -0.596528    2.408810e+09  2408810138
# 127840      38335       1        0    1 -0.944649    3.651237e+09  3651236699
# 124333      99123       0        2    1 -1.060689    3.557167e+09  3557167258
#
#         country      hour  dayofweek  is_weekend  is_fraud
# 542         181 -1.522122   1.489476    1.568716         0
# 58128       171 -0.798789  -1.501259   -0.637464         0
# 84711       171  1.226541   1.489476    1.568716         0
# 127840       56 -0.654123  -0.504347   -0.637464         0
# 124333      139  1.515874  -1.501259   -0.637464         0

# %%
final_df['user_id'].is_unique
# Out:
# True

# %% [markdown]
# ## ⚖️ Handle Class Imbalance (SMOTE)

# %%
features = merged_df[['purchase_value', 'time_since_signup', 'hour', 'dayofweek','is_weekend']]
target = merged_df['is_fraud']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, stratify=target)
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
X_resampled.shape
# Out:
# (191744, 5)

# %% [markdown]
# ## Credit

# %%
cc_df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# ### class inbalance

# %%
cc_df['Class'].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %% [markdown]
# ### scaling

# %%
cc_df['scaled_time'] = scaler.fit_transform(cc_df[['Time']])
cc_df['scaled_amount'] = scaler.fit_transform(cc_df[['Amount']])

#drop originals
cc_df.drop(['Time', 'Amount'], axis=1, inplace=True)
cc_df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.277838 -0.110474
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.771679  0.909412
# 3       0.237609  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.111864  1.014480
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.924384  0.012463
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.578229 -0.037501
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.800049 -0.163298
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.643078  0.376777
#
#              V24       V25       V26       V27       V28  Class  scaled_time  \
# 0       0.066928  0.128539 -0.189115  0.133558 -0.021053      0    -1.996583
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724      0    -1.996583
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0    -1.996562
# 3      -1.175575  0.647376 -0.221929  0.062723  0.061458      0    -1.996562
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153      0    -1.996541
# ...          ...       ...       ...       ...       ...    ...          ...
# 284802 -0.509348  1.436807  0.250034  0.943651  0.823731      0     1.641931
# 284803 -1.016226 -0.606624 -0.395255  0.068472 -0.053527      0     1.641952
# 284804  0.640134  0.265745 -0.087371  0.004455 -0.026561      0     1.641974
# 284805  0.123205 -0.569159  0.546668  0.108821  0.104533      0     1.641974
# 284806  0.008797 -0.473649 -0.818267 -0.002415  0.013649      0     1.642058
#
#         scaled_amount
# 0            0.244964
# 1           -0.342475
# 2            1.160686
# 3            0.140534
# 4           -0.073403
# ...               ...
# 284802      -0.350151
# 284803      -0.254117
# 284804      -0.081839
# 284805      -0.313249
# 284806       0.514355
#
# [284807 rows x 31 columns]

# %%
cc_df.to_csv("../../data/interim/interim_creditcard.csv", index=False)
