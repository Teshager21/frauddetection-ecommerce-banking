# %% [markdown]
# # 🧹 Data Preprocessing & EDA
# This notebook handles missing values, performs data cleaning, merges geolocation data, performs feature engineering, and prepares data for modeling.

# %% [markdown]
# ### 📦 Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import ipaddress

# %% [markdown]
# ## 📂 Load Data

# %%
fraud_df = pd.read_csv('../../data/raw/Fraud_Data.csv')
ip_df = pd.read_csv('../../data/raw/IpAddress_to_Country.csv')
cc_df = pd.read_csv('../../data/raw/creditcard.csv')

# %%
fraud_df.sample(5)
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 85832    371436  2015-01-07 17:58:27  2015-01-21 20:08:06              37
# 98726    305631  2015-02-12 20:19:56  2015-05-08 09:34:51              31
# 136073    15354  2015-06-06 01:31:09  2015-09-05 02:57:40              13
# 100244   357241  2015-02-12 15:20:02  2015-03-04 19:28:43              22
# 23513    102373  2015-02-23 10:05:41  2015-03-26 16:18:41              41
#
#             device_id  source browser sex  age    ip_address  class
# 85832   ANTQMUTAYPTFN     Ads  Chrome   M   24  3.757157e+09      1
# 98726   CSZSSLDHHUXBI     Ads  Chrome   M   24  3.407133e+09      0
# 136073  QJUVWBWPRFPCQ     SEO      IE   M   22  2.022262e+09      0
# 100244  OLLGEQPNYTTYZ     Ads  Safari   M   49  3.358263e+07      0
# 23513   RBHKFQBSVKXQD  Direct      IE   M   24  3.159428e+09      0

# %%
ip_df.sample(5)
# Out:
#         lower_bound_ip_address  upper_bound_ip_address             country
# 81975             3.254887e+09              3254886911  Russian Federation
# 43983             2.622620e+09              2622685183       United States
# 133630            3.561710e+09              3561717759              Poland
# 7739              1.075618e+09              1075621887       United States
# 112755            3.395076e+09              3395080191           Indonesia

# %%
cc_df.sample(5)
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 55457  46948.0 -0.977097  0.524320  0.489315 -0.058848 -0.328836  0.701093
# 18113  29198.0 -2.074129 -1.519325  1.770790 -2.751204 -0.495873 -0.644513
# 24055  33048.0  1.311467 -0.692340  0.227316 -0.751277 -0.704398  0.017826
# 8302   11084.0  1.052861  0.122419  0.658575  0.690618  0.195665  0.890361
# 26785  34251.0  1.275667 -0.935442  0.796874 -0.842222 -1.264062  0.222628
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 55457  0.479254  0.699701 -0.040778  ...  0.056808  0.029476  0.048463
# 18113  1.137406 -0.309236  1.733862  ...  0.065297  0.468279  0.221572
# 24055 -0.682405  0.128840 -0.761100  ...  0.069118  0.157845 -0.056990
# 8302  -0.397005  0.323601  1.373195  ... -0.273037 -0.419762  0.322584
# 26785 -1.295561  0.327107 -0.403311  ...  0.432035  1.085385 -0.122598
#
#             V24       V25       V26       V27       V28  Amount  Class
# 55457 -0.956106  0.044656  0.427833  0.169352  0.122904  150.00      0
# 18113 -0.080215  0.835380 -0.131732 -0.164362 -0.138222  293.94      0
# 24055 -0.292379  0.452364 -0.220789  0.011190 -0.002441   25.95      0
# 8302  -0.717545 -0.182686  0.166148  0.012429  0.000016    1.98      0
# 26785 -0.294331  0.308474 -0.013769  0.036093  0.008792   29.95      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 🧼 Data Cleaning

# %% [markdown]
# ### Missing Values

# %%
#count missing values in the df
fraud_df.isna().sum()
# Out:
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64

# %%
#check for missing values in the ip df
ip_df.isna().sum()
# Out:
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64

# %%
#check for missing values in credit card df
cc_df.isna().sum().sum()
# Out:
# 0

# %%
# Convert timestamps
fraud_df['signup_time'] = pd.to_datetime(fraud_df['signup_time'])
fraud_df['purchase_time'] = pd.to_datetime(fraud_df['purchase_time'])

# Remove duplicates
fraud_df.drop_duplicates(inplace=True)

# %%
fraud_df
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
# [151112 rows x 11 columns]

# %%
ip_df.dtypes
# Out:
# lower_bound_ip_address    float64
# upper_bound_ip_address      int64
# country                    object
# dtype: object

# %% [markdown]
# ## 🌐 IP Geolocation Mapping

# %%
fraud_df['ip_int'] = fraud_df['ip_address'].astype(float).astype(int)

# Make sure bounds are int
ip_df['lower_bound_ip_address'] = ip_df['lower_bound_ip_address'].astype(int)
ip_df['upper_bound_ip_address'] = ip_df['upper_bound_ip_address'].astype(int)

# Merge based on range: use pd.merge_asof or manual interval join
merged_df = pd.merge_asof(
    fraud_df.sort_values('ip_int'),
    ip_df.sort_values('lower_bound_ip_address'),
    left_on='ip_int',
    right_on='lower_bound_ip_address',
    direction='backward'
)

# Make sure bounds are int
merged_df['lower_bound_ip_address'] = merged_df['lower_bound_ip_address'].fillna(-1).astype('int')
merged_df['upper_bound_ip_address'] = merged_df['upper_bound_ip_address'].fillna(-1).astype('int')

# Optional: filter where ip_int is also <= upper_bound_ip_address
merged_df = merged_df[merged_df['ip_int'] <= merged_df['upper_bound_ip_address']]

# %%
merged_df.sample(5)
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 66894    330023 2015-04-18 06:55:02 2015-07-19 21:11:45              26
# 67004    393514 2015-02-14 13:49:54 2015-05-03 14:06:58              35
# 52376    250981 2015-07-14 18:08:19 2015-09-22 21:53:04              41
# 8313     229541 2015-03-16 07:58:06 2015-03-17 12:21:54              56
# 124708   169461 2015-05-22 15:19:48 2015-08-11 06:02:38              27
#
#             device_id  source  browser sex  age    ip_address  class  \
# 66894   JEXDPESBNUGOI  Direct       IE   F   31  1.918452e+09      0
# 67004   MFTROLCPDUVNH     Ads  FireFox   M   30  1.921333e+09      0
# 52376   ZGRXVAYSRQCOI     SEO       IE   F   28  1.481700e+09      0
# 8313    CMRRVJPYYBERM     Ads   Chrome   M   33  2.279901e+08      0
# 124708  SDIYDQSODDEJR     SEO   Chrome   M   23  3.567145e+09      0
#
#             ip_int  lower_bound_ip_address  upper_bound_ip_address  \
# 66894   1918452270              1917845504              1918894079
# 67004   1921333338              1921318912              1921384447
# 52376   1481699657              1481695232              1481703423
# 8313     227990061               226492416               234881023
# 124708  3567145094              3567124480              3567157247
#
#                            country
# 66894                        China
# 67004                     Malaysia
# 52376   Slovakia (SLOVAK Republic)
# 8313                 United States
# 124708              European Union

# %%
# Merge with country info
merged_df = pd.merge_asof(
    fraud_df.sort_values('ip_int'),
    ip_df.sort_values('lower_bound_ip_address'),
    left_on='ip_int', right_on='lower_bound_ip_address'
)
# Make sure bounds are int
merged_df['lower_bound_ip_address'] = merged_df['lower_bound_ip_address'].fillna(-1).astype('int')
merged_df['upper_bound_ip_address'] = merged_df['upper_bound_ip_address'].fillna(-1).astype('int')

# %%
merged_df.sample(5)
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 82860    387369 2015-01-02 11:49:46 2015-01-12 10:52:35              46
# 42472    313150 2015-01-07 08:15:55 2015-01-07 08:15:56              65
# 48717     38100 2015-03-18 05:13:22 2015-04-13 10:26:39              23
# 107346    45755 2015-02-14 21:03:52 2015-03-06 10:09:25              28
# 105371   372360 2015-07-24 23:58:28 2015-08-31 06:40:38              37
#
#             device_id source browser sex  age    ip_address  class  \
# 82860   DQSTTMOQVYKZW    SEO   Opera   M   42  2.357314e+09      0
# 42472   VRYLIRAQJIIIE    SEO   Opera   F   30  1.213105e+09      1
# 48717   NDXXJCCHZHCUG    SEO      IE   M   24  1.383218e+09      0
# 107346  TLYYFADISEHTN    Ads  Chrome   M   31  3.064825e+09      0
# 105371  MBZVVKFZADKNY    Ads      IE   M   23  3.008417e+09      0
#
#             ip_int  lower_bound_ip_address  upper_bound_ip_address  \
# 82860   2357314442            2.357264e+09            2.357330e+09
# 42472   1213104903            1.212940e+09            1.213202e+09
# 48717   1383218296            1.383211e+09            1.383219e+09
# 107346  3064824965            3.064824e+09            3.064832e+09
# 105371  3008416963            3.008365e+09            3.008627e+09
#
#                                 country
# 82860   Taiwan; Republic of China (ROC)
# 42472                     United States
# 48717                            Cyprus
# 107346                            Japan
# 105371                           Brazil

# %% [markdown]
# ## 🧠 Feature Engineering

# %%
# Time since signup
merged_df['time_since_signup'] = (merged_df['purchase_time'] - merged_df['signup_time']).dt.total_seconds() / 3600
# Hour and day of transaction
merged_df['hour_of_day'] = merged_df['purchase_time'].dt.hour
merged_df['day_of_week'] = merged_df['purchase_time'].dt.dayofweek

# %%
merged_df.sample(5)
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 112630   157735 2015-08-15 04:07:32 2015-09-14 20:26:34              34
# 39818    280723 2015-02-02 20:08:40 2015-03-21 20:11:20              49
# 28761      1297 2015-03-09 00:35:50 2015-05-12 20:42:58              64
# 14958    193149 2015-07-04 08:06:32 2015-08-12 12:45:20              34
# 50467    387328 2015-07-29 10:57:11 2015-08-05 01:50:19              43
#
#             device_id source browser sex  age    ip_address  class  \
# 112630  IMZOMEVVLIVUS    Ads  Safari   F   34  3.223526e+09      0
# 39818   NTDNDBLFSHJBU    Ads      IE   M   46  1.140383e+09      0
# 28761   TPMUFGIMXNNMN    Ads  Chrome   F   34  8.022669e+08      0
# 14958   RFJLLUQAADIOR    Ads  Chrome   F   22  4.126775e+08      0
# 50467   FMVXSXHZSPQFT    SEO  Chrome   M   47  1.429562e+09      0
#
#             ip_int  lower_bound_ip_address  upper_bound_ip_address  \
# 112630  3223525811            3.223526e+09            3.223526e+09
# 39818   1140383231            1.139802e+09            1.140851e+09
# 28761    802266868            7.969178e+08            8.053064e+08
# 14958    412677506            4.126638e+08            4.126802e+08
# 50467   1429561925            1.429209e+09            1.430258e+09
#
#               country  time_since_signup  hour_of_day  day_of_week
# 112630  United States         736.317222           20            0
# 39818   United States        1128.044444           20            5
# 28761          Canada        1556.118889           20            1
# 14958   United States         940.646667           12            2
# 50467           Spain         158.885556            1            2

# %% [markdown]
# ## ⚖️ Handle Class Imbalance (SMOTE)

# %%
features = merged_df[['purchase_value', 'time_since_signup', 'hour_of_day', 'day_of_week']]
target = merged_df['class']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, stratify=target)
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
features.sample(5)
# Out:
#         purchase_value  time_since_signup  hour_of_day  day_of_week
# 105069              50        1648.265833           20            4
# 73719               54        2832.614167           17            5
# 100111              23        1527.428056            3            1
# 23115               32         900.906944           18            2
# 19160               43        1578.668333           16            2
